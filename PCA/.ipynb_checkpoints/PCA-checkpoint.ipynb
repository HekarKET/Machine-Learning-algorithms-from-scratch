# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib 
import seaborn as sns
# %matplotlib inline

# %%
class PCA:
    def __init__(self,n_components=3):
        self.n_components  = n_components
    def fit(self,X):
        self.mean = np.mean(X, axis=0)
        X = X - self.mean
        cov = np.cov(X.T)
        eigenvalues, eigenvectors = np.linalg.eig(cov)
        eigenvectors = eigenvectors.T
        idxs = np.argsort(eigenvalues)[::-1]
        eigenvalues = eigenvalues[idxs]
        eigenvectors = eigenvectors[idxs]
        
        self.components = eigenvectors[0:self.n_components]

    def transform(self, X):
        # project data
        X = X - self.mean
        return np.dot(X, self.components.T)

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()
X = data.data
y = data.target
X.shape
# Out:
# (150, 4)

# %%
pca = PCA(2)
pca.fit(X)
X_transform = pca.transform(X)
X_transform.shape
# Out:
# (150, 2)

# %%
sns.scatterplot(X[:,0],X[:,1],hue=y)
plt.xlabel("PCA 1")
plt.ylabel("PCA 2")
# Out:
# C:\Users\Akhilesh\AppData\Roaming\Python\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'PCA 2')

# %%
sns.heatmap(np.cov(X_transform.T),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(np.cov(X.T),annot=True)
# Out:
# <AxesSubplot:>

# %%
import random
x = np.random.normal(0,1,(2,2000))
plt.plot(x[0] ,x[1] ,'b.')
sample = []
for i in range(2000):
    sample.append(random.uniform(0,2))
select = ((np.abs(x[0]) < sample) & (np.abs(x[1]) < sample))
plt.plot(x[0][select] ,x[1][select] ,'r.')
